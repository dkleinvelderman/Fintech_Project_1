# %%
import hvplot.pandas
import plotly.express as px
import plotly

# %%
# %run stock_data_cleaning.ipynb

# %%
total_df.hvplot.line(
    label="Company Stock Performance Over the Last Year",
    ylabel="Price in USD",
    xlabel="Time(Month/Year)",
    height=500,
    width = 1000
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
stock_plot()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)
